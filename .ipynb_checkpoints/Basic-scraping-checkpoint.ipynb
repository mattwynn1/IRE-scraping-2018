# %% [markdown]
# # Scraping FDA Warnings

# %% [markdown]
# Web scraping is the process of grabbing information off the internet. While it's powerful, it's also complex; just as all websites look and act differently, there's no one-size-fits-all solution to making it happen.
#
# Today we'll be going over some basic concepts while using the [FDA's Warning Letters](https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm). We'll start by grabbing the data we can see on the page. If time allows, we'll grab data for the whole year. And if this is the fastest-moving one-hour scraping course in the history of IRE, we'll look at how to grab ALL years.
#
# To start out with, we're going to grab three libraries that will help us through this process:

# %%
import requests
from bs4 import *
import csv

# %% [markdown]
# ### WTF was that
# Python is a programming language, no better or worse than Ruby, PHP, Perl or anything else. We're using it because it's pretty intuitive, and, well, it's what I'm best at. One of the great parts about Python is that there are a lot of handy tools already made for it by people much smarter than us. All we have to do is bring them in, which we do with the handy `import` command.
#
# In this case, we're bringing in three libraries:
# * [`requests`](http://docs.python-requests.org/en/master/) is a handy third-party library for making HTTP requests. It does the same thing your browser does when you type in a URL and hit enter -- sends a message to a server and requests a copy of the page. We'll use it to get Python the right pages to scrape.
# * [`BeautifulSoup`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a library you can use to parse HTML into data types that Python can work with. We'll use it to grab the contents of the page we want.
# * [`csv`](https://docs.python.org/2/library/csv.html) is a built-in library that reads and writes csv, which is of course God's chosen data format. Here, we'll be using it to spit out a csv for analysis.

# %%
url = "https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm"
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, "html5lib")
table = soup.find('table')

# %% [markdown]
# ### Requests and BeautifulSoup, brothers in arms
# Let's unpack what we just did there. First, we defined our url as the start page for this scrape. Now, rather than type the whole url, we can just say "url" and be good to go.
# We've set up a variable called "response" to hold our webpage in Python, and something called "html" which is the actual code that makes the page.
# We've created something called "soup," which is a BeautifulSoup representation of the page. This will let us pull it apart using the powerful parsing library.
# This process of getting a page and turning it into a BeautifulSoup object is really common in scraping, and for good reason. In the last bit, we use BeautifulSoup to track down the lone table on the page -- the very part we want to turn into a csv. Let's check that out:

# %%
print(table)
# Out:
# <table class="table table-bordered table-striped" id="WarningLetter_sortid" summary="Layout showing WarningLetter table with 5 columns: Letter Issue Date, Company Name, Issuing Office, Subject, Close Out Date">
#
# 		  <thead>
# 			<tr>
# 					<th data-toggle="true" data-type="numeric" scope="col"> Letter Issue Date </th>
# 					<th scope="col">  Company Name </th>
# 					<th data-hide="phone" scope="col">  Issuing Office </th>
# 					<th data-hide="phone" scope="col">  Subject </th>
# 					<th data-hide="phone,tablet" data-type="numeric" scope="col">  Close Out Date </th>
# 			</tr>
# 		  </thead>
# 		  <tbody>
#
#
#   <tr>
# 		 <td>05/31/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610084.htm">Vapestar</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/31/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609829.htm">Taiwan Biotech Co., LTD.</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/31/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610055.htm">Global Vapery</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/31/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609643.htm">Fair Fish Co., Inc.</a></td>
# 		 <td> New York District Office</td>
# 		 <td> Seafood HACCP/CGMP for Foods/Adulterated/Insanitary Conditions</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/30/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610073.htm">JSST Enterprises LLC</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609821.htm">Eassybuyonline</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609529.htm">LiquidCaffeine.com</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> Dietary Supplement/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609672.htm">XLPharmacy</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609749.htm">RxCash.Biz</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609814.htm">Medstore.biz</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609822.htm">AnonShop</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609527.htm">Dual Health Body and Mind</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> Dietary Supplement/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609818.htm">Instabill ECS‐Rx</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609739.htm">TramadolHub</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609762.htm">RemedyMart</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/29/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609780.htm">One Stop Pharma</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/24/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609165.htm">The Fertility Partnership LLC</a></td>
# 		 <td> Chicago District Office</td>
# 		 <td> Deviations/CFR/Regulations for Human Cells, Tissues &amp; Cellular Products (HCT/Ps)</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/23/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609195.htm">IDT Australia Ltd.</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/Active Pharmaceutical Ingredient (API)/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/23/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609133.htm">Creative Science, Inc.</a></td>
# 		 <td> Detroit District Office</td>
# 		 <td> Human Drug/Marketing/Animal Drug/Unsafe/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607901.htm">Kratom Spot</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608257.htm">GliSODin Skin Nutrients</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> New Drug/Labeling/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608259.htm">Sunergized LLC</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> New Drug/Labeling/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607904.htm">Revibe, Inc.</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608260.htm">Napa Valley Bioscience</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> New Drug/Labeling/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608716.htm">Performance Nutrition Formulators LLC dba VMI Sports</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> CGMP/Manufacturing, Packaging, Labeling, or Holding Operations for Dietary Supplements/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609136.htm">Kolmar Korea Co. Ltd.</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608214.htm">CV7 Holdings LLC</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> New Drug/Labeling/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608220.htm">Pharmacy Direct, PDU</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> New Drug/Labeling/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607903.htm">Front Range Kratom</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> Unapproved New Drug/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/18/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608717.htm">Jalco Cosmetics Pty Ltd.</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/17/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608709.htm">Orangeburg Pecan Company Inc</a></td>
# 		 <td> Atlanta District Office</td>
# 		 <td> CGMP/Food/Prepared, Packed or Held Under Insanitary Conditions/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/17/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609437.htm">Silver Armor, Inc.</a></td>
# 		 <td> Atlanta District Office</td>
# 		 <td> Unapproved New Drugs/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/16/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607950.htm">Europharma Concepts Limited</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/16/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607845.htm">New England Confectionery Company, Inc.</a></td>
# 		 <td> Center for Food Safety and Applied Nutrition</td>
# 		 <td> CGMP/Food/Prepared, Packed or Held Under Insanitary Conditions/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/15/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607695.htm">Cerno Pharmaceutical</a></td>
# 		 <td> Dallas District Office</td>
# 		 <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/14/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608713.htm">Jilin Shulan Synthetic Pharmaceutical Co. Ltd.</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/APIs/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/10/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605912.htm">13th Floor Elevapors, LLC</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/10/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605903.htm">Chill E-Liquid</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/10/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605909.htm">VallHund Vapes Inc.</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/10/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605925.htm">Virtue Vape, LLC</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/09/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607912.htm">Montana Compounding Pharmacy PC</a></td>
# 		 <td> Los Angeles District Office</td>
# 		 <td> Compounding Pharmacy/Adulterated Drug Products</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/09/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607820.htm">Nox Bellcow Cosmetics Co. Ltd.</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/09/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607583.htm">Reine Lifescience</a></td>
# 		 <td> Center for Drug Evaluation and Research</td>
# 		 <td> CGMP/Active Pharmaceutical Ingredient (API)/Adulterated</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/07/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607671.htm">Emmett F. Branigan, MD, PS, Inc</a></td>
# 		 <td> Los Angeles District Office</td>
# 		 <td> Deviations/CFR/Regulations for Human Cells, Tissues &amp; Cellular Products (HCT/Ps)</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/01/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605930.htm">Cosmic Fog Vapors LLC</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/01/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605819.htm">ACH Group, LLC d/b/a Candy Co E-Liquids</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/01/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605938.htm">Drip More LLC</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/01/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605397.htm">Sugoi LLC</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/01/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605893.htm">Omnia E-Liquid</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
#
#
#   <tr>
# 		 <td>05/01/2018 </td>
# 		 <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm605911.htm">Warrender Enterprise Inc.</a></td>
# 		 <td> Center for Tobacco Products</td>
# 		 <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# 		 <td nowrap="">
# 				<a href="#wldisclaimer">Not Issued *</a>
# 		</td>
#   </tr>
#
# 		</tbody>
# 		</table>

# %% [markdown]
# Wouldja Look at that! This is the power of BeautifulSoup: it understands html and translates to Python. By looking for the "table" tag in our soup, we identified the whole table of information we want. Now that we have it identified, we can start working on separating the information into the right shape to make a csv.

# %% [markdown]
# ### Thinking about data format
# Our end result is a csv. Because we have the handy-dandy `csv` module, we know that one easy way to get it done is to create a list, one of the Python data types (more on that in [IRE's fabulous intro to Python repo](https://github.com/cjwinchester/ire-2018-python-for-data-analysis/blob/master/reference/Python%20data%20types%20and%20basic%20syntax.ipynb)).
# To get there, we're going to create an empty list. Then we'll fill it in with the good stuff.

# %%
list_of_rows = []
for row in table.findAll('tr')[1:]:
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.encode('utf-8').strip()
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)
print(list_of_rows)
# Out:
# [[b'05/31/2018', b'Vapestar', b'Center for Tobacco Products', b'Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded', b'Not Issued *'], [b'05/31/2018', b'Taiwan Biotech Co., LTD.', b'Center for Drug Evaluation and Research', b'CGMP/Finished Pharmaceuticals/Adulterated', b'Not Issued *'], [b'05/31/2018', b'Global Vapery', b'Center for Tobacco Products', b'Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded', b'Not Issued *'], [b'05/31/2018', b'Fair Fish Co., Inc.', b'New York District Office', b'Seafood HACCP/CGMP for Foods/Adulterated/Insanitary Conditions', b'Not Issued *'], [b'05/30/2018', b'JSST Enterprises LLC', b'Center for Tobacco Products', b'Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded', b'Not Issued *'], [b'05/29/2018', b'Eassybuyonline', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'LiquidCaffeine.com', b'Center for Food Safety and Applied Nutrition', b'Dietary Supplement/Adulterated', b'Not Issued *'], [b'05/29/2018', b'XLPharmacy', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'RxCash.Biz', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'Medstore.biz', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'AnonShop', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'Dual Health Body and Mind', b'Center for Food Safety and Applied Nutrition', b'Dietary Supplement/Adulterated', b'Not Issued *'], [b'05/29/2018', b'Instabill ECS\xe2\x80\x90Rx', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'TramadolHub', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'RemedyMart', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/29/2018', b'One Stop Pharma', b'Center for Drug Evaluation and Research', b'Finished Pharmaceuticals/Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/24/2018', b'The Fertility Partnership LLC', b'Chicago District Office', b'Deviations/CFR/Regulations for Human Cells, Tissues & Cellular Products (HCT/Ps)', b'Not Issued *'], [b'05/23/2018', b'IDT Australia Ltd.', b'Center for Drug Evaluation and Research', b'CGMP/Active Pharmaceutical Ingredient (API)/Adulterated', b'Not Issued *'], [b'05/23/2018', b'Creative Science, Inc.', b'Detroit District Office', b'Human Drug/Marketing/Animal Drug/Unsafe/Adulterated', b'Not Issued *'], [b'05/18/2018', b'Kratom Spot', b'Center for Drug Evaluation and Research', b'Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/18/2018', b'GliSODin Skin Nutrients', b'Center for Food Safety and Applied Nutrition', b'New Drug/Labeling/Misbranded', b'Not Issued *'], [b'05/18/2018', b'Sunergized LLC', b'Center for Food Safety and Applied Nutrition', b'New Drug/Labeling/Misbranded', b'Not Issued *'], [b'05/18/2018', b'Revibe, Inc.', b'Center for Drug Evaluation and Research', b'Unapproved New Drug/Misbranded', b'Not Issued *'], [b'05/18/2018', b'Napa Valley Bioscience', b'Center for Food Safety and Applied Nutrition', b'New Drug/Labeling/Misbranded', b'Not Issued *'], [b'05/18/2018', b'Performance Nutrition Formulators LLC dba VMI Sports', b'Center for Food Safety and Applied Nutrition', b'CGMP/Manufacturing, Packaging, Labeling, or Holding Operations for Dietary Supplements/Adulterated', b'Not Issued *'], [b'05/18/2018', b'Kolmar Korea Co. Ltd.', b'Center for Drug Evaluation and Research', b'CGMP/Finished P ...

# %% [markdown]
# ### Grabbing the data
# Ok, let's step back through that:
# * `list_of_rows` starts out as an empty list.
# * `for,` and the associated indentation, indicates a loop. Anytime you see that, we're doing something a set number of times.
# * The `for row in table.findAll('tr')` section is going into our table and defining what, exactly, we're iterating over. In this case, it's each "tr" -- the html markup for a table row.
# * Every time we look at a row, we're going to store it in a temporary container called `list_of_cells`
# * Then, for every cell ('td' -- a table division in html) we're going to grab the text and show it into our `list_of_cells`
# * Once we've grabbed everything from the row, we'll put the whole thing into our `list_of_rows` and move on to the next one.
#
# Now that we have a list of lists, let's write it:

# %%
outfile = open('fdaresults.txt', 'wb')
writer = csv.writer(outfile)
writer.writerows(list_of_rows)

# %% [markdown]
# ### Writing the data
# This part, too, is fairly boilerplate anytime you want to turn a list of lists into a csv:
# * Open a file. In this case, it's called "fdaresults.txt"
# * Set up a way to write to that file using the `csv` library
# * Write the dang thing
#
# There we go! We successfully turned a table form a webpage into a csv. Underwhelmed? Me too. [In our next section](nuthin yet), we're going to take what we've learned and extrapolate a bit to get ALL the records from 2018.
